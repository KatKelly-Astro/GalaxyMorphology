# %%
import h5py
import matplotlib.pyplot as plt
import os
from os import listdir
from mpl_toolkits import mplot3d
import matplotlib.gridspec as gridspec
import numpy as np
import re
import pandas as pd

datasets = ['organic', 'gm_late', 'gm_early']

for dataset in datasets:
    print('-----------------------------------------')
    print(dataset)
    print('-----------------------------------------')
    
    files = listdir('C:\\Users\\katha\\GalaxyMorphology\\' + dataset)
    os.path.join("/C:", "Users","katha","GalaxyMorphology", dataset)

    count = 0

    galaxyAm = np.array(range(144), dtype=object).reshape(24,6)
    galaxyAm2 = np.array(range(144), dtype=object).reshape(24,6)
    galaxyAm3 = np.array(range(144), dtype=object).reshape(24,6)
    galaxyAm4 = np.array(range(144), dtype=object).reshape(24,6)
   
    for file in files:
    #if 1==1:



        #file = 'star_particles_015_z002p012.hdf5'
        #file = 'star_particles_028_z000p000.hdf5'
        
        # get redshift from the filename
        m = re.search('(z[0-9])\w+', file)
        s = m.group(0).replace('z', '')
        s = s.replace('p', '.')
        redshift = float(s)
        
        # load data for a particular galaxy at a particular redshift
        f = h5py.File('C:\\Users\\katha\\GalaxyMorphology\\' + dataset + '/' + file,'r')

        # extract data from the file
        ds_c = f['Coordinates']
        ds_v = f['Velocity']                    
        ds_m = f['Mass']
        
        
        # Calculate the maginitude of the velocity vector
        import numpy as np
        vel = np.array(ds_v[0:1])
        velvec = np.linalg.norm(vel)
        
        # calculate Ekin
        EKin = (0.5)*(ds_m[0:1])*((velvec)**2)

        # Store totals of all particles for each redshift in the current galaxy
        galaxyAm[count, 0] = redshift
        galaxyAm2[count, 0] = ds_m[0:1]
        galaxyAm3[count, 0] = velvec
        galaxyAm4[count, 0] = EKin
              
        count = count + 1
        

    for n in range(24):
            print('file name:   '+ file   +  '\t redshift:   ' + str(galaxyAm[n][0]) + '\t mass:   ' + str(galaxyAm2[n][0]) + '\t mag of velcoity vector:   ' + str(galaxyAm3[n][0]) + '\t Kinetic energy:   ' + str(galaxyAm4[n][0]))
# Out:
# -----------------------------------------
# organic
# -----------------------------------------
# file name:   star_particles_028_z000p000.hdf5	 redshift:   7.05	 mass:   [736106.64167352]	 mag of velcoity vector:   110.57880039810792	 Kinetic energy:   [4.50043495e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   5.971	 mass:   [499810.80562982]	 mag of velcoity vector:   57.49097849693746	 Kinetic energy:   [8.25990488e+08]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   5.487	 mass:   [571699.90597443]	 mag of velcoity vector:   80.51214647792726	 Kinetic energy:   [1.8529382e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   5.037	 mass:   [536163.93213463]	 mag of velcoity vector:   12.157571563597056	 Kinetic energy:   [39624269.53615312]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   4.485	 mass:   [487067.2259946]	 mag of velcoity vector:   58.04980180340071	 Kinetic energy:   [8.20654574e+08]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   3.984	 mass:   [502856.49747548]	 mag of velcoity vector:   124.42172544141422	 Kinetic energy:   [3.89230182e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   3.528	 mass:   [608130.79988707]	 mag of velcoity vector:   60.93439468600146	 Kinetic energy:   [1.12899497e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   3.017	 mass:   [514484.88815602]	 mag of velcoity vector:   115.04703830069523	 Kinetic energy:   [3.40481495e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   2.478	 mass:   [498850.2862067]	 mag of velcoity vector:   48.781814067698654	 Kinetic energy:   [5.93548379e+08]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   2.237	 mass:   [491636.84536822]	 mag of velcoity vector:   188.26403573164845	 Kinetic energy:   [8.71262769e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   2.012	 mass:   [490142.17525865]	 mag of velcoity vector:   239.5793685382846	 Kinetic energy:   [1.40666574e+10]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   1.737	 mass:   [725078.81223355]	 mag of velcoity vector:   93.70197700102511	 Kinetic energy:   [3.18311792e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   1.487	 mass:   [491097.98969951]	 mag of velcoity vector:   90.99930562773665	 Kinetic energy:   [2.0333602e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   1.259	 mass:   [689593.99831573]	 mag of velcoity vector:   124.70493045306867	 Kinetic energy:   [5.36204836e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   1.004	 mass:   [496074.56299795]	 mag of velcoity vector:   195.62212629992234	 Kinetic energy:   [9.49189473e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.865	 mass:   [433102.97235181]	 mag of velcoity vector:   133.81116099577352	 Kinetic energy:   [3.87744679e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.736	 mass:   [939023.06223763]	 mag of velcoity vector:   312.4117940429679	 Kinetic energy:   [4.58248555e+10]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.615	 mass:   [697631.18961043]	 mag of velcoity vector:   291.3448568251138	 Kinetic energy:   [2.96081045e+10]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.503	 mass:   [840403.82202348]	 mag of velcoity vector:   149.78511688713832	 Kinetic energy:   [9.42747411e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.366	 mass:   [478247.65563937]	 mag of velcoity vector:   77.6444170963478	 Kinetic energy:   [1.44159518e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.271	 mass:   [455878.4935166]	 mag of velcoity vector:   374.3112791966298	 Kinetic energy:   [3.19363248e+10]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.183	 mass:   [419714.43158603]	 mag of velcoity vector:   299.5423642097251	 Kinetic energy:   [1.88295705e+10]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.101	 mass:   [451712.47509196]	 mag of velcoity vector:   395.8729109712984	 Kinetic energy:   [3.53951419e+10]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.0	 mass:   [3608101.19633512]	 mag of velcoity vector:   368.88406012951225	 Kinetic energy:   [2.45486997e+11]
# -----------------------------------------
# gm_late
# -----------------------------------------
# file name:   star_particles_028_z000p000.hdf5	 redshift:   7.05	 mass:   [521868.19507795]	 mag of velcoity vector:   50.993904157790936	 Kinetic energy:   [6.78527355e+08]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   5.971	 mass:   [530602.04822776]	 mag of velcoity vector:   65.19538661955386	 Kinetic energy:   [1.12764567e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   5.487	 mass:   [506081.84393088]	 mag of velcoity vector:   65.65449598991057	 Kinetic energy:   [1.09073614e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   5.037	 mass:   [620517.44983406]	 mag of velcoity vector:   29.40454071513567	 Kinetic energy:   [2.68258075e+08]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   4.485	 mass:   [515411.01253645]	 mag of velcoity vector:   31.00177413776002	 Kinetic energy:   [2.47683339e+08]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   3.984	 mass:   [544752.30939636]	 mag of velcoity vector:   92.95623729380296	 Kinetic energy:   [2.35356478e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   3.528	 mass:   [482462.07589294]	 mag of velcoity vector:   39.80720221293129	 Kinetic energy:   [3.82257923e+08]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   3.017	 mass:   [548156.17477613]	 mag of velcoity vector:   166.73965207617232	 Kinetic energy:   [7.61994957e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   2.478	 mass:   [499669.98064374]	 mag of velcoity vector:   155.59492050846924	 Kinetic energy:   [6.04844997e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   2.237	 mass:   [529907.98222493]	 mag of velcoity vector:   105.80001026619678	 Kinetic energy:   [2.96580017e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   2.012	 mass:   [456785.04084443]	 mag of velcoity vector:   71.67762201273717	 Kinetic energy:   [1.17340803e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   1.737	 mass:   [587259.66084973]	 mag of velcoity vector:   83.79346655105637	 Kinetic energy:   [2.06167635e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   1.487	 mass:   [467406.45716213]	 mag of velcoity vector:   51.9504370285343	 Kinetic energy:   [6.30729469e+08]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   1.259	 mass:   [471803.23603823]	 mag of velcoity vector:   62.55942520379274	 Kinetic energy:   [9.23243841e+08]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   1.004	 mass:   [456824.24902988]	 mag of velcoity vector:   37.28936843512461	 Kinetic energy:   [3.17606374e+08]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.865	 mass:   [432352.71696322]	 mag of velcoity vector:   105.28940555683111	 Kinetic energy:   [2.39650061e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.736	 mass:   [597082.47403015]	 mag of velcoity vector:   71.9156757455656	 Kinetic energy:   [1.5440148e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.615	 mass:   [480995.58159664]	 mag of velcoity vector:   118.38941098296594	 Kinetic energy:   [3.37082969e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.503	 mass:   [521835.5846837]	 mag of velcoity vector:   93.37695850098925	 Kinetic energy:   [2.27500913e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.366	 mass:   [484515.12464355]	 mag of velcoity vector:   87.08883054402625	 Kinetic energy:   [1.83739386e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.271	 mass:   [464736.67717447]	 mag of velcoity vector:   130.56657784277186	 Kinetic energy:   [3.96132975e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.183	 mass:   [469167.95925377]	 mag of velcoity vector:   63.356272346042125	 Kinetic energy:   [9.4162414e+08]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.101	 mass:   [468450.36833967]	 mag of velcoity vector:   43.256390515376175	 Kinetic energy:   [4.38262331e+08]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.0	 mass:   [449755.60807627]	 mag of velcoity vector:   89.4682199163077	 Kinetic energy:   [1.80004841e+09]
# -----------------------------------------
# gm_early
# -----------------------------------------
# file name:   star_particles_028_z000p000.hdf5	 redshift:   7.05	 mass:   [520561.12937572]	 mag of velcoity vector:   23.500832532743104	 Kinetic energy:   [1.43750127e+08]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   5.971	 mass:   [604101.98307137]	 mag of velcoity vector:   39.61314788194196	 Kinetic energy:   [4.73978864e+08]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   5.487	 mass:   [511835.98314709]	 mag of velcoity vector:   247.31642975661595	 Kinetic energy:   [1.56533305e+10]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   5.037	 mass:   [651919.63708167]	 mag of velcoity vector:   120.09116363738336	 Kinetic energy:   [4.70095586e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   4.485	 mass:   [606783.60663505]	 mag of velcoity vector:   114.20492566079402	 Kinetic energy:   [3.95706801e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   3.984	 mass:   [514193.23333653]	 mag of velcoity vector:   49.61437865402791	 Kinetic energy:   [6.32865579e+08]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   3.528	 mass:   [609758.56150614]	 mag of velcoity vector:   89.20603055527552	 Kinetic energy:   [2.4261427e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   3.017	 mass:   [546646.84891725]	 mag of velcoity vector:   172.97767639373694	 Kinetic energy:   [8.17818577e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   2.478	 mass:   [567447.57546155]	 mag of velcoity vector:   270.49970045062634	 Kinetic energy:   [2.07600945e+10]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   2.237	 mass:   [458512.47237492]	 mag of velcoity vector:   497.2139848221109	 Kinetic energy:   [5.66771272e+10]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   2.012	 mass:   [643124.83548359]	 mag of velcoity vector:   93.96130000572023	 Kinetic energy:   [2.83898645e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   1.737	 mass:   [486004.17040651]	 mag of velcoity vector:   106.57567508008249	 Kinetic energy:   [2.76010869e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   1.487	 mass:   [498991.11119279]	 mag of velcoity vector:   357.39379414271195	 Kinetic energy:   [3.18681482e+10]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   1.259	 mass:   [461893.35364598]	 mag of velcoity vector:   304.9701971915856	 Kinetic energy:   [2.14796163e+10]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   1.004	 mass:   [547645.81940223]	 mag of velcoity vector:   265.13056352251874	 Kinetic energy:   [1.92481667e+10]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.865	 mass:   [471359.18305793]	 mag of velcoity vector:   254.89495526958427	 Kinetic energy:   [1.5312442e+10]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.736	 mass:   [433423.37082725]	 mag of velcoity vector:   282.4270014610112	 Kinetic energy:   [1.728601e+10]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.615	 mass:   [505645.09178511]	 mag of velcoity vector:   416.7789739503294	 Kinetic energy:   [4.39164678e+10]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.503	 mass:   [426332.12432672]	 mag of velcoity vector:   278.66832131049694	 Kinetic energy:   [1.65536308e+10]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.366	 mass:   [472401.09326601]	 mag of velcoity vector:   136.7495335503052	 Kinetic energy:   [4.41705295e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.271	 mass:   [467932.27948919]	 mag of velcoity vector:   287.639235666782	 Kinetic energy:   [1.93574997e+10]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.183	 mass:   [431330.81644978]	 mag of velcoity vector:   277.18909299468714	 Kinetic energy:   [1.65703914e+10]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.101	 mass:   [422601.37084082]	 mag of velcoity vector:   138.55672474127	 Kinetic energy:   [4.05654337e+09]
# file name:   star_particles_028_z000p000.hdf5	 redshift:   0.0	 mass:   [436545.47807435]	 mag of velcoity vector:   162.94490260164957	 Kinetic energy:   [5.79536851e+09]
