# %%
import pandas as pd
from pandas import DataFrame
import csv
df_organic = pd.read_csv("halo_catalogue_organic.txt", delim_whitespace=True, header=None, skiprows=(0, 0), names=['Index','Time (Gyr)','a_exp','magnitude','subhalo centre X','subhalo centre Y','subhalo centre Z','subhalo peculiar velocity X','subhalo peculiar velocity Y','subhalo peculiar velocity Z','Halo mass','Stellar mass','BH mass','SFR','sSFR'] )
df_early = pd.read_csv("halo_catalogue_gm_early.txt", delim_whitespace=True, header=None, skiprows=(0, 0), names=['Index','Time (Gyr)','a_exp','magnitude','subhalo centre X','subhalo centre Y','subhalo centre Z','subhalo peculiar velocity X','subhalo peculiar velocity Y','subhalo peculiar velocity Z','Halo mass','Stellar mass','BH mass','SFR','sSFR'] )
df_late = pd.read_csv("halo_catalogue_gm_late.txt", delim_whitespace=True, header=None, skiprows=(0, 0), names=['Index','Time (Gyr)','a_exp','magnitude','subhalo centre X','subhalo centre Y','subhalo centre Z','subhalo peculiar velocity X','subhalo peculiar velocity Y','subhalo peculiar velocity Z','Halo mass','Stellar mass','BH mass','SFR','sSFR'] )
df
# Out:
#     Index  Time (Gyr)  a_exp  magnitude  subhalo centre X  subhalo centre Y  \
# 0       2       0.476  0.091      9.993             4.048             0.730
# 1       3       0.550  0.100      8.988             4.454             0.799
# 2       4       0.635  0.110      8.075             4.900             0.875
# 3       5       0.760  0.124      7.050             5.600             1.329
# 4       6       0.942  0.143      5.971             6.364             1.117
# 5       7       1.049  0.154      5.487             6.935             1.590
# 6       8       1.168  0.166      5.037             7.448             1.681
# 7       9       1.348  0.182      4.485             8.070             1.381
# 8      10       1.556  0.201      3.984             8.877             1.505
# 9      11       1.795  0.221      3.528             9.762             1.641
# 10     12       2.144  0.249      3.017            11.132             2.252
# 11     13       2.653  0.287      2.478            12.856             2.360
# 12     14       2.949  0.309      2.237            13.788             2.465
# 13     15       3.276  0.332      2.012            14.766             2.622
# 14     16       3.767  0.365      1.737            16.206             2.745
# 15     17       4.325  0.402      1.487            17.754             2.876
# 16     18       4.958  0.443      1.259            19.418             2.976
# 17     19       5.864  0.499      1.004            21.709             3.126
# 18     20       6.472  0.536      0.865            23.286             3.216
# 19     21       7.131  0.576      0.736            24.988             3.271
# 20     22       7.841  0.619      0.615            26.753             3.348
# 21     23       8.603  0.665      0.503            28.627             3.426
# 22     24       9.698  0.732      0.366            31.366             3.490
# 23     25      10.577  0.787      0.271            33.577             3.549
# 24     26      11.501  0.846      0.183            35.951             3.627
# 25     27      12.469  0.909      0.101            38.492             3.737
# 26     28      13.821  1.000      0.000            42.109             3.885
#
#     subhalo centre Z  subhalo peculiar velocity X  \
# 0              3.345                      -21.856
# 1              3.673                      -25.320
# 2              4.031                      -33.067
# 3              4.347                      -35.168
# 4              5.205                      -30.115
# 5              5.381                      -41.249
# 6              5.777                      -45.835
# 7              6.541                      -38.917
# 8              7.155                      -41.672
# 9              7.832                      -59.219
# 10             8.603                      -63.162
# 11             9.872                      -74.110
# 12            10.567                      -97.686
# 13            11.330                      -83.045
# 14            12.420                     -103.584
# 15            13.604                     -133.558
# 16            14.909                     -127.281
# 17            16.664                     -107.950
# 18            17.828                     -102.145
# 19            19.072                     -122.223
# 20            20.395                     -127.539
# 21            21.784                     -130.556
# 22            23.817                     -129.706
# 23            25.466                     -137.800
# 24            27.240                     -148.658
# 25            29.166                     -159.048
# 26            31.989                     -194.300
#
#     subhalo peculiar velocity Y  subhalo peculiar velocity Z     Halo mass  \
# 0                       -57.702                     -107.591  4.370600e+09
# 1                       -59.936                     -118.378  5.911400e+09
# 2                       -59.146                     -122.241  8.016200e+09
# 3                      -168.075                      -36.773  1.691900e+10
# 4                       -70.994                     -148.108  2.310800e+10
# 5                      -193.422                      -43.126  3.094600e+10
# 6                      -195.636                      -51.056  3.428200e+10
# 7                       -79.613                     -178.890  5.208700e+10
# 8                       -77.190                     -182.936  7.813400e+10
# 9                       -86.418                     -182.991  9.477300e+10
# 10                     -255.758                      -68.888  1.168200e+11
# 11                     -165.371                     -133.448  1.882900e+11
# 12                     -157.335                     -121.338  3.143700e+11
# 13                     -228.928                     -105.642  7.188600e+11
# 14                     -235.849                     -111.294  9.840200e+11
# 15                     -240.763                     -109.943  1.273600e+12
# 16                     -235.731                     -109.787  2.195900e+12
# 17                     -220.498                     -124.221  2.473700e+12
# 18                     -227.819                     -127.175  2.411200e+12
# 19                     -235.654                     -137.093  2.349300e+12
# 20                     -228.459                     -136.367  2.502900e+12
# 21                     -222.157                     -137.820  2.709300e+12
# 22                     -220.262                     -137.152  2.705200e+12
# 23                     -204.404                     -134.120  2.747600e+12
# 24                     -180.322                     -119.502  3.005000e+12
# 25                     -165.999                      -95.603  3.129000e+12
# 26                     -159.952                      -73.718  3.198800e+12
#
#     Stellar mass     BH mass        SFR          sSFR
# 0   1.096800e+07         0.0   0.075048  6.842300e-09
# 1   1.784500e+07         0.0   0.004368  2.447900e-10
# 2   1.957100e+07         0.0   0.055810  2.851700e-09
# 3   2.020900e+07    734810.0   0.202340  1.001300e-08
# 4   3.568900e+07    734810.0   0.174820  4.898500e-09
# 5   7.787400e+07    734810.0   0.321770  4.131900e-09
# 6   8.277200e+07    734810.0   0.103300  1.248100e-09
# 7   1.012500e+08    734810.0   0.427730  4.224600e-09
# 8   1.435300e+08    734810.0   0.186170  1.297100e-09
# 9   2.225500e+08   1469900.0   0.280820  1.261800e-09
# 10  4.298200e+08    734810.0   1.197800  2.786700e-09
# 11  4.006300e+08   2215600.0   0.395530  9.872700e-10
# 12  7.989200e+08   2951600.0   1.280700  1.603000e-09
# 13  1.917900e+09   4464700.0   7.408200  3.862600e-09
# 14  5.142900e+09   5934300.0  17.772000  3.455600e-09
# 15  1.191500e+10  11942000.0  18.172000  1.525200e-09
# 16  2.180900e+10  17446000.0  19.888000  9.119000e-10
# 17  2.746700e+10  30772000.0   9.507300  3.461400e-10
# 18  2.884900e+10  31503000.0   5.116200  1.773400e-10
# 19  3.110700e+10  33293000.0   4.986900  1.603100e-10
# 20  4.264400e+10  44155000.0   6.197800  1.453400e-10
# 21  4.759300e+10  51633000.0   4.498700  9.452500e-11
# 22  5.065200e+10  63429000.0   2.709900  5.350000e-11
# 23  5.147900e+10  67776000.0   2.643700  5.135500e-11
# 24  5.222800e+10  70165000.0   2.841500  5.440600e-11
# 25  5.292200e+10  75923000.0   2.240600  4.233900e-11
# 26  5.400200e+10  78532000.0   1.710700  3.167800e-11

# %%
# Halo Mass plots
# To do:
# deviation


import matplotlib.pyplot as plt
# import numpy as np

# Create a data frame for each of the catalogues
plt.plot(df_early['Time (Gyr)'],df_early['Halo mass'], linewidth=1, color='maroon', label='Early')

plt.plot(df_late['Time (Gyr)'],df_late['Halo mass'], linewidth=1, color='blue', label='Late')

plt.plot(df_organic['Time (Gyr)'],df_organic['Halo mass'], linewidth=1, color='darkgreen', label='Organic')

# Plot the y-axis on a log scale
plt.yscale("log")

# Label the x and y axis
plt.xlabel('Time (Gyr)')
plt.ylabel('$Log_{10}$ Halo Mass ($M_{\odot}$)')

# Add a legend using the labels in the df plot lines above
plt.legend(loc="lower right")

# Add a plot title
plt.title('Halo mass variation')

# OPTIONAL FORMATTING
#ax = plt.axes()
#ax.set_facecolor("grey")
#plt.grid(color='red', linestyle='-.', linewidth=0.7)
#x_ticks = np.arange(0, 15, 1)
#plt.xticks(x_ticks)
# Out:
# Text(0.5,1,'Halo mass variation')

# %%
# Stellar Mass
# To do:
# deviation


# Create a data frame for each of the catalogues
plt.plot(df_early['Time (Gyr)'],df_early['Stellar mass'], linewidth=1, color='maroon', label='Early')

plt.plot(df_late['Time (Gyr)'],df_late['Stellar mass'], linewidth=1, color='blue', label='Late')

plt.plot(df_organic['Time (Gyr)'],df_organic['Stellar mass'], linewidth=1, color='darkgreen', label='Organic')

# Plot the y-axis on a log scale
plt.yscale("log")

# Label the x and y axis
plt.xlabel('Time (Gyr)')
plt.ylabel('$Log_{10}$ Stellar Mass ($M_{\odot}$)')

# Add a legend using the labels in the df plot lines above
plt.legend(loc="lower right")

# Add a plot title
plt.title('Stellar mass variation')
# Out:
# Text(0.5,1,'Stellar mass variation')

# %%
# Black Hole Mass
# To do:
# deviation


# Create a data frame for each of the catalogues
plt.plot(df_early['Time (Gyr)'],df_early['BH mass'], linewidth=1, color='maroon', label='Early')

plt.plot(df_late['Time (Gyr)'],df_late['BH mass'], linewidth=1, color='blue', label='Late')

plt.plot(df_organic['Time (Gyr)'],df_organic['BH mass'], linewidth=1, color='darkgreen', label='Organic')

# Plot the y-axis on a log scale
plt.yscale("log")

# Label the x and y axis
plt.xlabel('Time (Gyr)')
plt.ylabel('$Log_{10}$ Black Hole Mass ($M_{\odot}$)')

# Add a legend using the labels in the df plot lines above
plt.legend(loc="lower right")

# Add a plot title
plt.title('Black Hole Mass variation')
# Out:
# Text(0.5,1,'Black Hole Mass variation')

# %%
# How to plot peculiar velocity when I have three columns X, Y, Z?

# %%
# Star formation rate
# To do:
# deviation
# change scale so early types fit in plot

# Create a data frame for each of the catalogues
plt.plot(df_early['Time (Gyr)'],df_early['SFR'], linewidth=1, color='maroon', label='Early')

plt.plot(df_late['Time (Gyr)'],df_late['SFR'], linewidth=1, color='blue', label='Late')

plt.plot(df_organic['Time (Gyr)'],df_organic['SFR'], linewidth=1, color='darkgreen', label='Organic')

# Plot the y-axis on a log scale
plt.yscale("log")

# Label the x and y axis
plt.xlabel('Time (Gyr)')
plt.ylabel('$Log_{10}$ Star Formation Rate ($M_{\odot} y^{-1}$)')

# Add a legend using the labels in the df plot lines above
plt.legend(loc="lower right")

# Add a plot title
plt.title('Star Formation Rate variation')
# Out:
# Text(0.5,1,'Star Formation Rate variation')

# %%
# Specific Star formation rate
# To do:
# deviation
# change scale so early types fit in plot

# Create a data frame for each of the catalogues
plt.plot(df_early['Time (Gyr)'],df_early['sSFR'], linewidth=1, color='maroon', label='Early')

plt.plot(df_late['Time (Gyr)'],df_late['sSFR'], linewidth=1, color='blue', label='Late')

plt.plot(df_organic['Time (Gyr)'],df_organic['sSFR'], linewidth=1, color='darkgreen', label='Organic')

# Plot the y-axis on a log scale
plt.yscale("log")

# Label the x and y axis
plt.xlabel('Time (Gyr)')
plt.ylabel('$Log_{10}$ Specific Star Formation Rate ($y^{-1}$)')

# Add a legend using the labels in the df plot lines above
plt.legend(loc="lower right")

# Add a plot title
plt.title('Specific Star Formation Rate variation')
# Out:
# Text(0.5,1,'Specific Star Formation Rate variation')
