# %%
#The very first thing you’ll need to do is to open the file for reading
>>> import h5py
>>> f = h5py.File('star_particles_005_z007p050.hdf5', 'r')

# %%
#f['Coordinates'][...]

# %%
#f['Velocity'][...]

# %%
#f['Mass'][...]

# %%
import matplotlib.pyplot as plt
fig, ax=plt.subplots()
ax.hist(f['Mass'], bins=[500000, 600000, 700000, 800000])
ax.set_xticks([500000, 600000, 700000, 800000])
plt.xlabel('Mass ($M_{\odot}$)')
plt.ylabel("Count")
plt.title('Mass Histogram at redshift = 7.050')
plt.show()

# %%
fig, ax=plt.subplots()

Co = (f['Coordinates'])
x = Co[:,0]
y = Co[:,1]
ax.scatter(x, y)
#plt.rcParams["figure.figsize"] = (10, 10)
plt.xlabel("X coordinates (Mpc)")
plt.ylabel("Y coordinates (Mpc)")
plt.ylim(-0.002,0.004)
plt.xlim(-0.003,0.003)
plt.title('X vs Y Coordinates at redshift = 7.050')
plt.show()

# %%
#The very first thing you’ll need to do is to open the file for reading
>>> import h5py
>>> f = h5py.File('star_particles_028_z000p000.hdf5', 'r')

# %%
fig, ax=plt.subplots()

Co = (f['Coordinates'])
x = Co[:,0]
y = Co[:,1]
z = Co[:,2]
ax.scatter(x, y, z)
#plt.rcParams["figure.figsize"] = (10, 10)
plt.xlabel("X coordinates (Mpc)")
plt.ylabel("Y coordinates (Mpc)")
plt.title('X vs Y Coordinates at redshift = 0')
plt.show()
# Out:
# C:\Users\katha\Anaconda3\lib\site-packages\matplotlib\collections.py:853: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec


fig, ax=plt.subplots()

gs = gridspec.GridSpec(2,2)
gs.update(wspace=0, hspace=0)


ax1 = fig.add_subplot(spec[0, 0])
ax2 = fig.add_subplot(spec[0, 1])
ax3 = fig.add_subplot(spec[1, 0])
ax4 = fig.add_subplot(spec[1, 1])


ax1 = plt.subplot(gs[1])
ax1.plot(y, x, marker='.', markersize=0.5, alpha=0.2,)
ax1.xaxis.set_visible(False)
ax1.set_ylabel('y (Mpc)', rotation=90, labelpad=15)

ax2 = plt.subplot(gs[1])
ax2.plot (y, x, marker='.', markersize=0.5, alpha=0.2,)
ax2.yaxis.set_visible(False)
ax2.set_xlabel('z (Mpc)', rotation=0)

ax3 = plt.subplot(gs[2])
ax3.plot (x, z,  marker='.', markersize=0.5, alpha=0.2,)
ax3.set_ylabel('z (Mpc)', rotation=90, labelpad=15)
ax3.set_xlabel('x (Mpc)')

ax4.yaxis.set_visible(False)
ax4.xaxis.set_visible(False)
ax4.spines['right'].set_visible(False)
ax4.spines['bottom'].set_visible(False)
ax4.spines['top'].set_visible(False)
ax4.spines['left'].set_visible(False)

fig.set_size_inches(18.5, 10.5, forward=True)
